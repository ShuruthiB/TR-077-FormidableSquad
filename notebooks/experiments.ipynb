# %% [markdown]
# # Renewable Energy Forecasting Experiments - Ooty
#
# This notebook contains exploratory data analysis and model experimentation for the Ooty solar-wind hybrid plant.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.preprocessing.pipeline import load_and_preprocess

df = load_and_preprocess('../data/raw/sample_ooty_energy.csv')
df.head()

# %% [markdown]
# ## Exploratory Data Analysis

# %%
plt.figure(figsize=(15, 6))
df['energy_kwh'].plot()
plt.title('Energy Generation Time Series')
plt.show()

# %% [markdown]
# ## Feature Correlation

# %%
sns.heatmap(df.corr(), annot=False)
plt.show()
